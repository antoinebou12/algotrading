# %% [markdown]
# # RSI

# %%
# %pip install --upgrade pip
# %pip install novalabs-backtest
# %pip install pandas
# %pip install requests
# %pip install numpy
# %pip install pytz
# %pip install setuptools
# %pip install python-decouple
# %pip install aiohttp
# %pip install matplotlib
# %pip install asyncio
# %pip install gql
# %pip install ta
# %pip install bcrypt
# %pip install schedule
# %pip install novalabs-backtest

# %%
from novalabs.utils.backtest import BackTest

import pandas as pd
import numpy as np
from datetime import datetime, timedelta

from ta.momentum import rsi
pd.options.mode.chained_assignment = None

# %%
class RSI(BackTest):
    """
    A backtesting strategy using the RSI indicator to generate buy and sell signals.

    Args:
        exchange: Exchange name
        strategy_name: Name of the strategy
        candle: Candle size
        list_pair: List of pairs to backtest
        start: Start date
        end: End date
        fees: Fees
        start_bk: Starting balance
        leverage: Leverage
        max_pos: Maximum number of positions
        max_holding: Maximum holding time
        quote_asset: Quote asset
        geometric_sizes: Use geometric sizes
        # Specific to Backtest Analysis
        save_all_pairs_charts: Save all pairs charts
        update_data: Update data
        plot_exposure: Plot exposure
        key: API key
        secret: API secret
        passphrase: API passphrase

    """
    def __init__(
        self,
        exchange: str,
        strategy_name: str,
        candle: str,
        list_pair,
        start: datetime,
        end: datetime,
        start_bk: float,
        leverage: int,
        max_pos: int,
        max_holding: timedelta,
        quote_asset: str = 'USDT',
        geometric_sizes: bool = False,
        save_all_pairs_charts: bool = False,
        plot_exposure: bool = False,
        key: str = "",
        secret: str = "",
        passphrase: str = "",
        tp_sl_delta: float = 0.005
    ):

        self.tp_sl_delta = tp_sl_delta

        super().__init__(
            exchange = exchange,
            strategy_name = strategy_name,
            candle = candle,
            list_pairs = list_pair,
            start = start,
            end = end,
            start_bk = start_bk,
            leverage = leverage,
            max_pos = max_pos,
            max_holding = max_holding,
            quote_asset = quote_asset,
            geometric_sizes = geometric_sizes,
            plot_all_pairs_charts = save_all_pairs_charts,
            plot_exposure = plot_exposure,
            key = key,
            secret = secret,
            passphrase = passphrase
        )

    def build_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Adds the RSI indicator to the dataframe.
        Args:
            df (pd.DataFrame): the dataframe to add the RSI indicator to.
        Returns:
            df (pd.DataFrame): the dataframe with the RSI indicator added.
        """

        df['rsi'] = rsi(df['close'])

        return df

    def entry_strategy(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Generates buy and sell signals based on the RSI indicator.
        Args:
            df (pd.DataFrame): the dataframe to generate buy and sell signals for.
        Returns:
            df (pd.DataFrame): the dataframe with buy and sell signals generated.
        """
        df['entry_signal'] = np.nan
        df['take_profit'] = np.nan
        df['stop_loss'] = np.nan
        df['position_size'] = 1

        long_conditions = (df['rsi'] < 30) & (df['rsi'].shift(1) > 30)
        short_conditions = (df['rsi'] > 70) & (df['rsi'].shift(1) < 70)
        df['entry_signal'] = np.where(long_conditions, 1, np.where(short_conditions, -1, np.nan))

        df['take_profit'] = np.where(df['entry_signal'] == 1, df['close'] * (1 + self.tp_sl_delta), np.where(df['entry_signal'] == -1, df['close'] * (1 - self.tp_sl_delta), np.nan))
        df['stop_loss'] = np.where(df['entry_signal'] == 1, df['close'] * (1 - self.tp_sl_delta), np.where(df['entry_signal'] == -1, df['close'] * (1 + self.tp_sl_delta), np.nan))

        return df

    def exit_strategy(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Args:
            df: Dataframe returned bu self.entry_strategy()
        Returns:
            All information necessary for exit points
        """

        # df['exit_signal'] = np.where(df['exit_point'] < self.exit_probability, 1, 0)
        df['exit_signal'] = np.nan

        return df

# %%
strat = RSI(
    exchange = 'binance',
    strategy_name = 'RSI',
    candle = '1h',
    list_pair = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'SOLUSDT', 'DOGEUSDT'],
    start =  datetime(2021, 1, 1),
    end =  datetime(2023, 1, 1),
    start_bk = 1000,
    leverage = 5,
    max_pos = 2,
    max_holding = timedelta(hours=12),
    quote_asset = 'USDT',
    geometric_sizes = True,
    save_all_pairs_charts = False,
    plot_exposure = False,
    key = "",
    secret = "",
    passphrase = "",
    tp_sl_delta = 0.05
)

stats = strat.run_backtest()
# Out:
# ##### ERROR : Service unavailable from a restricted location according to 'b. Eligibility' in https://www.binance.com/en/terms. Please contact customer service if you believe you received this message in error. #####
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 strat = RSI(
#       2     exchange = 'binance',
#       3     strategy_name = 'MACD',
#       4     candle = '1h',
#       5     list_pair = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'SOLUSDT', 'DOGEUSDT'],
#       6     start =  datetime(2021, 1, 1),
#       7     end =  datetime(2023, 1, 1),
#       8     start_bk = 1000,
#       9     leverage = 5,
#      10     max_pos = 2,
#      11     max_holding = timedelta(hours=12),
#      12     quote_asset = 'USDT',
#      13     geometric_sizes = True,
#      14     save_all_pairs_charts = False,
#      15     plot_exposure = False,
#      16     key = "",
#      17     secret = "",
#      18     passphrase = "",
#      19     tp_sl_delta = 0.05
#      20 )
#      22 stats = strat.run_backtest()
#
# Cell In[2], line 52, in RSI.__init__(self, exchange, strategy_name, candle, list_pair, start, end, start_bk, leverage, max_pos, max_holding, quote_asset, geometric_sizes, save_all_pairs_charts, plot_exposure, key, secret, passphrase, tp_sl_delta)
#      28 def __init__(
#      29     self,
#      30     exchange: str,
#    (...)
#      47     tp_sl_delta: float = 0.005
#      48 ):
#      50     self.tp_sl_delta = tp_sl_delta
# ---> 52     super().__init__(
#      53         exchange = exchange,
#      54         strategy_name = strategy_name,
#      55         candle = candle,
#      56         list_pairs = list_pair,
#      57         start = start,
#      58         end = end,
#      59         start_bk = start_bk,
#      60         leverage = leverage,
#      61         max_pos = max_pos,
#      62         max_holding = max_holding,
#      63         quote_asset = quote_asset,
#      64         geometric_sizes = geometric_sizes,
#      65         plot_all_pairs_charts = save_all_pairs_charts,
#      66         plot_exposure = plot_exposure,
#      67         key = key,
#      68         secret = secret,
#      69         passphrase = passphrase
#      70     )
#
# File ~/.local/lib/python3.10/site-packages/novalabs/utils/backtest.py:106, in BackTest.__init__(self, exchange, strategy_name, candle, list_pairs, start, end, start_bk, leverage, max_pos, max_holding, quote_asset, geometric_sizes, plot_all_pairs_charts, plot_exposure, key, secret, passphrase, backtest_id)
#     103     else:
#     104         self.list_pairs = raw_list_pairs
# --> 106 self._verify_all_pairs()
#     107 self.client.pairs_info = self.client.get_pairs_info(quote_asset=quote_asset)
#     109 # Initialize DataFrames
#
# File ~/.local/lib/python3.10/site-packages/novalabs/utils/backtest.py:178, in BackTest._verify_all_pairs(self)
#     177 def _verify_all_pairs(self):
# --> 178     all_pairs = self.get_list_pairs()
#     180     for pair in self.list_pairs:
#     181         assert pair in all_pairs, f"{pair} is not a valid trading pair.\nHere is the list of all available pairs on {self.exchange}:\n{all_pairs}"
#
# File ~/.local/lib/python3.10/site-packages/novalabs/utils/backtest.py:173, in BackTest.get_list_pairs(self)
#     167 def get_list_pairs(self) -> list:
#     168     """
#     169
#     170     Returns:
#     171          list of all available pairs on the exchange.
#     172     """
# --> 173     info = self.client.get_pairs_info(quote_asset=self.quote_asset)
#     175     return list(info.keys())
#
# File ~/.local/lib/python3.10/site-packages/novalabs/clients/binance.py:355, in Binance.get_pairs_info(self, quote_asset)
#     348 info = self._send_request(
#     349     end_point=f"/fapi/v1/exchangeInfo",
#     350     request_type="GET",
#     351 )
#     353 output = {}
# --> 355 for symbol in info['symbols']:
#     356     if symbol['contractType'] == 'PERPETUAL' and symbol['status'] == 'TRADING' and symbol[
#     357         'quoteAsset'] == quote_asset:
#     359         pair = symbol['symbol']
#
# KeyError: 'symbols'

# %%
pd.DataFrame(stats)
